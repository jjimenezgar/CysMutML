# %% [markdown]
# # Dataset Exploration
# Load `data/processed/fireprotdb_mutations.csv` and summarize target/condition distributions. Core logic belongs in `src/`.

# %%
import pandas as pd

df = pd.read_csv('../data/processed/fireprotdb_mutations.csv', low_memory=False)
df.head()
