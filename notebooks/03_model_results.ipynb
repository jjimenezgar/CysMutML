# %% [markdown]
# # Model Results
# Use only completed, leakage-safe outputs. Do not treat toy metrics as scientific results.

# %%
import pandas as pd

pd.read_csv('../results/synthetic/regression_cv_metrics.csv').head()
