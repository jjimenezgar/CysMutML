# %% [markdown]
# # Model Results
#
# Compact developer view of the versioned, leakage-safe model comparison. For the reviewer-facing analysis, use `CysMutML_Portfolio_Demo.ipynb`.

# %%
import pandas as pd

metrics = pd.read_csv('../results/physchem_model_comparison/regression_cv_metrics.csv')
metrics.groupby('model')[['mae', 'rmse', 'r2', 'pearson', 'spearman']].agg(['mean', 'std']).round(3)
