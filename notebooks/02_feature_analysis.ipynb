# %% [markdown]
# # Feature Analysis
# Inspect feature distributions generated by `cysmutml build-features`.

# %%
import pandas as pd

df = pd.read_csv('../data/processed/fireprotdb_features.csv', low_memory=False)
df[['delta_hydrophobicity','delta_volume','blosum62']].describe()
